# %%
import os
import glob
import numpy as np
from utils import *
from tqdm import tqdm_notebook as tqdm

# %matplotlib inline

# %% [markdown]
# ## Basic Parameters

# %%
ri_folder = '/media/share/HDD2TB/cTDM/RI/healthy/0419sun_532/'
ext = '.raw'
ri_bg=1.567
voxel_size = 0.21855

# %% [markdown]
# ## Start measurement

# %%
for ri_path in glob.glob(ri_folder +'*'+ ext)[:1]:
    tmp_filename = os.path.basename(ri_path).split('.')[:2]
    filename = str(tmp_filename[0]).rsplit('_',2)[0]
    
    if os.path.isfile(ri_path):
        print(ri_path)
        
        drawFig(ri_path,voxel_size)
# Out:
# /media/share/HDD2TB/cTDM/RI/healthy/0419sun_532/1.raw
# Resolution of x-axis: 0.920 (um)
# Resolution of y-axis: 1.026 (um)
# Resolution of z-axis: 2.025 (um)

# %%
drawFig('./3D-RI-Real_512x512x512.rimap',voxel_size)
# Out:
# Resolution of x-axis: 0.972 (um)
# Resolution of y-axis: 1.339 (um)
# Resolution of z-axis: 3.531 (um)
